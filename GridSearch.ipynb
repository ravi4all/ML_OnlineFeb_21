# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
df = pd.read_csv('pima-indians-diabetes.data.csv', header=None)

# %%
df.shape
# Out:
# (768, 9)

# %%
df.head()
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
pipeline = make_pipeline(MinMaxScaler(), LogisticRegression(solver='liblinear'))

# %%
pipeline
# Out:
# Pipeline(steps=[('minmaxscaler', MinMaxScaler()),
#                 ('logisticregression', LogisticRegression(solver='liblinear'))])

# %%
alphas = [0.1,0.2,0.5,1.0,2.0,5.0,10.0]
penalty = ['l1', 'l2']
params = {
    'logisticregression__C' : alphas,
    'logisticregression__penalty' : penalty
}

# %%
grid = GridSearchCV(pipeline, param_grid=params, cv=5)

# %%
grid.fit(X,y)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('minmaxscaler', MinMaxScaler()),
#                                        ('logisticregression',
#                                         LogisticRegression(solver='liblinear'))]),
#              param_grid={'logisticregression__C': [0.1, 0.2, 0.5, 1.0, 2.0, 5.0,
#                                                    10.0],
#                          'logisticregression__penalty': ['l1', 'l2']})

# %%
grid.best_params_
# Out:
# {'logisticregression__C': 10.0, 'logisticregression__penalty': 'l1'}

# %%
grid.best_score_
# Out:
# 0.7721840251252015

# %%
pd.DataFrame(grid.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003983      0.001102         0.000998    1.093451e-03
# 1        0.001987      0.000889         0.000804    7.484434e-04
# 2        0.003599      0.000483         0.000601    4.908475e-04
# 3        0.001384      0.000486         0.000613    5.005029e-04
# 4        0.005406      0.000485         0.000592    4.838485e-04
# 5        0.001795      0.000400         0.000392    4.803758e-04
# 6        0.007372      0.001353         0.000997    8.583069e-07
# 7        0.001795      0.000399         0.000399    4.881691e-04
# 8        0.006981      0.000643         0.001196    3.840102e-04
# 9        0.001596      0.000476         0.000200    3.993988e-04
# 10       0.007373      0.000507         0.000406    4.970491e-04
# 11       0.001989      0.000013         0.000206    4.111290e-04
# 12       0.008165      0.000403         0.000406    4.972794e-04
# 13       0.001993      0.000630         0.000598    4.881923e-04
#
#    param_logisticregression__C param_logisticregression__penalty  \
# 0                          0.1                                l1
# 1                          0.1                                l2
# 2                          0.2                                l1
# 3                          0.2                                l2
# 4                          0.5                                l1
# 5                          0.5                                l2
# 6                            1                                l1
# 7                            1                                l2
# 8                            2                                l1
# 9                            2                                l2
# 10                           5                                l1
# 11                           5                                l2
# 12                          10                                l1
# 13                          10                                l2
#
#                                                params  split0_test_score  \
# 0   {'logisticregression__C': 0.1, 'logisticregres...           0.668831
# 1   {'logisticregression__C': 0.1, 'logisticregres...           0.681818
# 2   {'logisticregression__C': 0.2, 'logisticregres...           0.746753
# 3   {'logisticregression__C': 0.2, 'logisticregres...           0.733766
# 4   {'logisticregression__C': 0.5, 'logisticregres...           0.740260
# 5   {'logisticregression__C': 0.5, 'logisticregres...           0.753247
# 6   {'logisticregression__C': 1.0, 'logisticregres...           0.753247
# 7   {'logisticregression__C': 1.0, 'logisticregres...           0.759740
# 8   {'logisticregression__C': 2.0, 'logisticregres...           0.759740
# 9   {'logisticregression__C': 2.0, 'logisticregres...           0.766234
# 10  {'logisticregression__C': 5.0, 'logisticregres...           0.766234
# 11  {'logisticregression__C': 5.0, 'logisticregres...           0.766234
# 12  {'logisticregression__C': 10.0, 'logisticregre...           0.772727
# 13  {'logisticregression__C': 10.0, 'logisticregre...           0.759740
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.675325           0.655844           0.660131
# 1            0.694805           0.675325           0.673203
# 2            0.727273           0.772727           0.777778
# 3            0.701299           0.720779           0.725490
# 4            0.727273           0.772727           0.797386
# 5            0.707792           0.727273           0.777778
# 6            0.759740           0.759740           0.790850
# 7            0.733766           0.740260           0.803922
# 8            0.753247           0.746753           0.810458
# 9            0.753247           0.753247           0.797386
# 10           0.753247           0.753247           0.810458
# 11           0.753247           0.740260           0.803922
# 12           0.753247           0.753247           0.810458
# 13           0.746753           0.740260           0.810458
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.666667         0.665359        0.006796               14
# 1            0.653595         0.675749        0.013397               13
# 2            0.745098         0.753926        0.018773               10
# 3            0.679739         0.712215        0.019432               12
# 4            0.771242         0.761777        0.025024                9
# 5            0.751634         0.743545        0.023977               11
# 6            0.764706         0.765657        0.013112                7
# 7            0.777778         0.763093        0.025594                8
# 8            0.764706         0.766981        0.022564                6
# 9            0.771242         0.768271        0.016199                4
# 10           0.771242         0.770885        0.021024                2
# 11           0.784314         0.769595        0.022513                3
# 12           0.771242         0.772184        0.020896                1
# 13           0.777778         0.766998        0.025229                5
